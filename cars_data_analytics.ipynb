# %%
# ========================
# 🚗 Cars Dataset Analysis
# ========================

# 📌 Step 1: Import Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configure plots
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10,6)

# ========================
# 📌 Step 2: Load Dataset
# ========================
df = pd.read_csv("/content/cars.csv")

print("Shape of dataset:", df.shape)
df.head()
# Out:
# Shape of dataset: (65029, 24)
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1      2018          4  Silver
# 1  Bentley    Arnage         10_1  10_1$$2      2018          6    Grey
# 2  Bentley    Arnage         10_1  10_1$$3      2017         11    Blue
# 3  Bentley    Arnage         10_1  10_1$$4      2018          4   Green
# 4  Bentley    Arnage         10_1  10_1$$5      2017         11    Grey
#
#    Reg_year Bodytype Runned_Miles  ... Engine_power Annual_Tax Wheelbase  \
# 0      2000   Saloon        60000  ...          NaN        NaN    3116.0
# 1      2002   Saloon        44000  ...        450.0        315    3116.0
# 2      2002   Saloon        55000  ...        400.0        315    3116.0
# 3      2003   Saloon        14000  ...          NaN        NaN    3116.0
# 4      2003   Saloon        61652  ...          NaN        NaN    3116.0
#
# ...

# %%
# 📌 Step 3: Explore Dataset
print("\nDataset Info:")
print(df.info())

print("\nSummary Statistics:")
print(df.describe())

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65029 entries, 0 to 65028
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Maker         65029 non-null  object
#  1    Genmodel     65029 non-null  object
#  2    Genmodel_ID  65029 non-null  object
#  3   Adv_ID        65029 non-null  object
#  4   Adv_year      65029 non-null  int64
#  5   Adv_month     65029 non-null  int64
#  6   Color         60015 non-null  object
#  7   Reg_year      65029 non-null  int64
#  8   Bodytype      64833 non-null  object
#  9   Runned_Miles  64756 non-null  object
#  10  Engin_size    64883 non-null  object
#  11  Gearbox       64992 non-null  object
#  12  Fuel_type     64979 non-null  object
#  13  Price         65029 non-null  int64
#  14  Engine_power  57839 non-null  float64
#  15  Annual_Tax    54408 non-null  object
#  16  Wheelbase     57250 non-null  float64
# ...

# %%
# ========================
# 📌 Step 4: Visualizations
# ========================

# 1. Distribution of Car Prices (Histogram + KDE)
plt.figure()
sns.histplot(df['Price'], kde=True, bins=30, color="blue")
plt.title("Distribution of Car Prices")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# 2. Car Prices by Fuel Type (Boxplot)
plt.figure()
sns.boxplot(x="Fuel_type", y="Price", data=df, palette="Set2")
plt.title("Car Prices by Fuel Type")
plt.show()

# 3. Engine Size vs Price (Scatterplot)
plt.figure()
sns.scatterplot(x="Engin_size", y="Price", hue="Fuel_type", data=df, alpha=0.7)
plt.title("Engine Size vs Price")
plt.show()

# 4. Horsepower vs Price (Regression Plot)
plt.figure()
sns.regplot(x="Engine_power", y="Price", data=df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title("Horsepower vs Price")
plt.show()

# 5. Price by Transmission (Violin Plot)
plt.figure()
sns.violinplot(x="Gearbox", y="Price", data=df, palette="muted")
plt.title("Car Prices by Transmission Type")
plt.show()

# 6. Average Price by Fuel Type (Bar Plot)
plt.figure()
sns.barplot(x="Fuel_type", y="Price", data=df, estimator="mean", ci=None, palette="coolwarm")
plt.title("Average Car Price by Fuel Type")
plt.show()
# Out:
# /tmp/ipython-input-530967576.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Fuel_type", y="Price", data=df, palette="Set2")
# /tmp/ipython-input-530967576.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Gearbox", y="Price", data=df, palette="muted")
# /tmp/ipython-input-530967576.py:39: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Fuel_type", y="Price", data=df, estimator="mean", ci=None, palette="coolwarm")
# /tmp/ipython-input-530967576.py:39: FutureWarning:
#
# ...
